# %% [markdown]
# # Gated Map-Ant MLP Curriculum
#
# Historical launcher for the gated curriculum that grows map size and ant count with the original MLP critic.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
while PROJECT_ROOT != PROJECT_ROOT.parent and not (PROJECT_ROOT / "pyproject.toml").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
PACKAGE_ROOT = PROJECT_ROOT / "src" / "ant_byte_env"
sys.path.insert(0, str(PACKAGE_ROOT.parent))

CONFIG = PROJECT_ROOT / "experiments" / "map_ant_gated_mlp_curriculum.json"
CONFIG

# %%
from ant_byte_env.cli import main as ant_byte_main

ant_byte_main([
    "train",
    "jax",
    "--config",
    str(CONFIG),
    "--dry-run",
])

# %%
RUN_TRAINING = False

if RUN_TRAINING:
    ant_byte_main([
        "train",
        "jax",
        "--config",
        str(CONFIG),
    ])
